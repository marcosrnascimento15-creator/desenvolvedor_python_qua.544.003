# %% [markdown]
# # Titulo do meu documento
#
# Nesta aula, iremos aprender sobre como inserir ***markdowns*** dentro de arquivos do tipo **Jupyter Notebook**.
#
#
# > ***Markdown*** é um tipo de coumento muito usado em ciência de dados e tambpem para alimentar Inteligência Artificial.
# >
# > Manipular este tipo de arquivo se torna fundamental para dominar as profissões do futuro que dependem de IAs.

# %% [markdown]
# ## Subtítulo de markdown
#
# O que diferencia um markdown de um notebook, é oque caso de notebook, ele tabmém é capaz de ler códigos das linguagens de programação *R*, *Julia* e é claro, *Pyton*.

# %% [markdown]
# ## Checklist
#
# ### linguagens de programação aceitas em notebooks
#
# ✅ Python<br>
# ✅ Julia<br>
# ✅ R
#
# ### linguagens que iremos utilizar no curso
#
# ✅ Python<br>
# ❌ Julia<br>
# ❌ R
